# %% [markdown]
# # Install the necessary packages

# %%
pip install wheel
pip install pipwin

pipwin install numpy
pipwin install pandas
pipwin install shapely
pipwin install gdal
pipwin install fiona
pipwin install pyproj
pipwin install six
pipwin install rtree
pipwin install geopandas

# %%
# !pip install geojson
# !pip install shapely
# !pip install geopandas
# !pip install geojsonio

# %% [markdown]
# # Import the necessary packages

# %%
#to import the geojson as a pandas like dataframe
import geopandas as gpd
import pandas as pd
import os
import cv2
import random

# %% [markdown]
# # Exploratory Data Analysis

# %%
XVIEW_UTILS_PATH = r'C:\Users\bcper\Documents\GitHub'
TF_INSTALL_PATH = r'C:\Users\bcper\Documents\GitHub\models'
GEOJSON_FILE = 'xView_train.geojson'
CLASS_LABELS_FILE = 'Class Labels.txt'

# %%
#Filenames and locations
DATA_DIR_PATH = os.path.join(TF_INSTALL_PATH, 'workspace','data', '')

paths = {
    'WORK_PATH': os.path.join(TF_INSTALL_PATH, 'workspace'),
    'DATA_PATH': DATA_DIR_PATH,
    'IMAGE_PATH': r'C:\Users\bcper\Documents\GitHub\models\workspace\data\train_images'
}

files = {
    'GEOJSON_IN': os.path.join(paths['DATA_PATH'], GEOJSON_FILE),
    'GEOJSON_OUT': os.path.join(paths['DATA_PATH'], GEOJSON_FILE + '_' + 'rare'),
    'CLASS_LABELS': os.path.join(paths['DATA_PATH'], CLASS_LABELS_FILE)
}

# %%
#read in the geojson
regions = gpd.read_file(files['GEOJSON_IN'])

# %%
used_ids = regions.type_id.unique()

# %%
os.chdir(paths['DATA_PATH'])
#read in the class labels
class_dict = {}
file = open(files['CLASS_LABELS'], "r")

#create a class label dictionary
for line in file:
    key, value = line.split(':')
    class_dict[int(key)] = value.strip()
    
given_ids = [key for key, vals in class_dict.items()]

# %%
extra_classes = [item for item in used_ids if item not in given_ids]

print(extra_classes)
# Out:
# [75, 82]

# %%
#split the bounds box
names = ["x1", "y1", "x2", "y2"]
regions[names] = regions['bounds_imcoords'].str.split(',', expand=True)
regions[names] = regions[names].astype(int)
regions['bottom'] = regions.y2 - regions.y1
regions['top'] = regions.x2 - regions.x1
regions['area'] = regions.bottom * regions.top

# %%
#delete any rows which contain a bounding box with a small x or y dimension
prior = len(regions)
regions = regions[regions.top > 10]
regions = regions[regions.bottom > 10]
post = len(regions)
print('Removed {} small regions.'.format(prior-post))

prior = len(regions)
regions = regions[~regions.type_id.isin(extra_classes)]
post = len(regions)
print('Removed {} invalid id types.'.format(prior-post))


prior = len(regions)
regions = regions[regions.x1 >0]
regions = regions[regions.x2 >0]
regions = regions[regions.y1 >0]
regions = regions[regions.y2 >0]
post = len(regions)
print('Removed {} bboxes off the image.'.format(prior-post))
# Out:
# Removed 0 small regions.
# Removed 0 invalid id types.
# Removed 0 bboxes off the image.

# %%
#the area of the bounding box in pixels
regions.hist(column='area', bins=50, range=(0,1000))
# Out:
# array([[<AxesSubplot:title={'center':'area'}>]], dtype=object)

# %%
regions['ratio'] = regions.top / regions.bottom
regions.hist(column='ratio', bins=25, range=(0.25,3))
# Out:
# array([[<AxesSubplot:title={'center':'ratio'}>]], dtype=object)

# %%
#the x size of the bounding box in pixels
regions.hist(column='top', bins=25, range=(0,200))
# Out:
# array([[<AxesSubplot:title={'center':'top'}>]], dtype=object)

# %%
#the y size of the bounding box in pixels
regions.hist(column='bottom', bins=25, range=(0,150))
# Out:
# array([[<AxesSubplot:title={'center':'bottom'}>]], dtype=object)

# %%
regions.type_id.value_counts()
# Out:
# 73    309592
# 18     92311
# 23      9790
# 19      5548
# 24      4591
# 83      4126
# 25      3431
# 27      3108
# 21      2447
# 89      2269
# 35      1789
# 86      1590
# 34      1585
# 91      1311
# 17      1231
# 60      1210
# 41      1177
# 79      1161
# 72      1156
# 76      1066
# 77       896
# 28       820
# 64       818
# 26       753
# 13       674
# 47       652
# 71       614
# 63       602
# 42       597
# 40       596
# 20       586
# 50       442
# 93       364
# 12       361
# 61       330
# 59       325
# 51       305
# 65       268
# 44       219
# 53       198
# 74       198
# 49       192
# 45       185
# 55       172
# 32       169
# 54       152
# 29       141
# 84       121
# 38       120
# 37       118
# 36       117
# 94        83
# 66        80
# 52        76
# 11        73
# 15        70
# 62        68
# 56        68
# 57        62
# 33        16
# Name: type_id, dtype: int64

# %%
regions
# Out:
#             bounds_imcoords        edited_by            cat_id  type_id  \
# 0       2712,1145,2746,1177  wwoscarbecerril  1040010028371A00       73
# 1       2720,2233,2760,2288  wwoscarbecerril  1040010028371A00       73
# 2       2687,1338,2740,1399  wwoscarbecerril  1040010028371A00       73
# 3       2691,1201,2730,1268  wwoscarbecerril  1040010028371A00       73
# 4         2671,838,2714,869  wwoscarbecerril  1040010028371A00       73
# ...                     ...              ...               ...      ...
# 601932    710,1900,738,1925  wwoscarbecerril  1040010029A6F400       73
# 601933    2091,258,2138,295  wwoscarbecerril  1040010029A6F400       73
# 601934    2106,361,2124,379  wwoscarbecerril  1040010029A6F400       73
# 601935      1917,38,1958,64  wwoscarbecerril  1040010029A6F400       73
# 601936      2323,55,2349,74  wwoscarbecerril  1040010029A6F400       73
#
#                              ingest_time  index_right  image_id  \
# 0       2017-07-24T12:49:09.118000+00:00         2356  2355.tif
# 1       2017-07-24T17:26:05.701000+00:00         2356  2355.tif
# 2       2017-07-24T12:45:09.081000+00:00         2356  2355.tif
# 3       2017-07-24T12:49:09.118000+00:00         2356  2355.tif
# 4       2017-07-24T13:20:38.279999+00:00         2356  2355.tif
# ...                                  ...          ...       ...
# 601932  2017-07-20T19:53:58.250999+00:00          389   389.tif
# 601933  2017-07-20T19:58:09.621000+00:00          389   389.tif
# 601934  2017-07-20T19:58:09.621000+00:00          389   389.tif
# 601935  2017-07-20T20:00:09.628000+00:00          389   389.tif
# 601936  2017-07-20T20:01:06.747000+00:00          389   389.tif
#
#                                                point_geom  feature_id  \
# 0       0101000020E6100000616E4E6406A256C03BE6ADA0D621...      374410
# 1       0101000020E6100000042D0CC705A256C0004F7071E71F...      394393
# 2       0101000020E6100000B29F7E4707A256C0000AE6537921...      374031
# 3       0101000020E6100000CE53137207A256C00EBF7084B521...      374409
# 4       0101000020E610000060DE147608A256C05D6A384C6122...      377368
# ...                                                   ...         ...
# 601932  0101000020E6100000CF0EE83357B958406B326375013F...      319871
# 601933  0101000020E610000000632E73A6B95840B722198AA84A...      320284
# 601934  0101000020E610000056BA697BA6B958407F027597FE49...      320300
# 601935  0101000020E61000003C99A0629CB95840CE2F5BD4444C...      320500
# 601936  0101000020E610000066CC2912B3B95840C97ECDAB2B4C...      320643
#
#          grid_file                                           geometry    x1  \
# 0        Grid2.shp  POLYGON ((-90.53170 14.56604, -90.53170 14.566...  2712
# 1        Grid2.shp  POLYGON ((-90.53167 14.56222, -90.53167 14.562...  2720
# 2        Grid2.shp  POLYGON ((-90.53179 14.56527, -90.53179 14.565...  2687
# 3        Grid2.shp  POLYGON ((-90.53177 14.56572, -90.53177 14.565...  2691
# 4        Grid2.shp  POLYGON ((-90.53184 14.56710, -90.53184 14.567...  2671
# ...            ...                                                ...   ...
# 601932  Grid97.shp  POLYGON ((98.89590 3.65572, 98.89590 3.65581, ...   710
# 601933  Grid97.shp  POLYGON ((98.90070 3.66139, 98.90070 3.66152, ...  2091
# 601934  Grid97.shp  POLYGON ((98.90075 3.66110, 98.90075 3.66116, ...  2106
# 601935  Grid97.shp  POLYGON ((98.90010 3.66220, 98.90010 3.66229, ...  1917
# 601936  Grid97.shp  POLYGON ((98.90151 3.66216, 98.90151 3.66223, ...  2323
#
#           y1    x2    y2  bottom  top  area     ratio relative_area
# 0       1145  2746  1177      32   34  1088  1.062500         large
# 1       2233  2760  2288      55   40  2200  0.727273         large
# 2       1338  2740  1399      61   53  3233  0.868852         large
# 3       1201  2730  1268      67   39  2613  0.582090         large
# 4        838  2714   869      31   43  1333  1.387097         large
# ...      ...   ...   ...     ...  ...   ...       ...           ...
# 601932  1900   738  1925      25   28   700  1.120000         large
# 601933   258  2138   295      37   47  1739  1.270270         large
# 601934   361  2124   379      18   18   324  1.000000        medium
# 601935    38  1958    64      26   41  1066  1.576923         large
# 601936    55  2349    74      19   26   494  1.368421         large
#
# [463190 rows x 20 columns]

# %%
#regions['area'] = regions['area'].astype('int64')

regions['relative_area'] = 'large'

regions.loc[regions['area'] <= 400, 'relative_area'] = 'medium'
regions.loc[regions['area'] <= 200, 'relative_area'] = 'small'
count = regions['type_id'].groupby(regions['relative_area']).count()
print(count)
# Out:
# relative_area
# large     329790
# medium     85167
# small      48233
# Name: type_id, dtype: int64

# %%
counts = regions.groupby(['relative_area', 'type_id']).size()
print(counts)
# Out:
# relative_area  type_id
# large          11          72
#                12         361
#                13         674
#                15          69
#                17          56
#                          ...
# small          84           4
#                86          64
#                89           1
#                91          23
#                94           1
# Length: 146, dtype: int64

# %%
regions.hist(column='type_id', bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'type_id'}>]], dtype=object)

# %%
#save a new geoJSON file to be used later
regions.drop(columns=names)
regions.drop(columns=['bottom', 'top', 'ratio', 'area'])
regions.to_file(files['GEOJSON_OUT'], driver='GeoJSON')
# Out:
#   File "<ipython-input-20-1d801b8fc72c>", line 2
#     regions.drop(columns=names)as
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # View images and overlay bounding boxes

# %%
image_name = '2568.tif'
id_type_wanted = used_ids

#id_type_wanted = [94]


test_image = os.path.join(paths['IMAGE_PATH'], image_name)
test_regions = regions[regions['image_id'] == image_name]

image = cv2.imread(test_image)
window_name = 'Image'
#create a color dictionary for the different ID types
color_dict = {}
type_set = test_regions.type_id.unique()

# font needed for text
font = cv2.FONT_HERSHEY_SIMPLEX

for type_id in type_set:
    color_dict[type_id] = (random.randint(0,255), random.randint(0,255), random.randint(0,255))


#loop through the region and find all of the objects, then place them on the image
for i in range(len(test_regions)):
    lst_int = [int(x) for x in test_regions.iloc[i]['bounds_imcoords'].split(",")]

    id_type = test_regions.type_id.iloc[i]
    topleft = (lst_int[0], lst_int[1])
    
    bottomright = (lst_int[2], lst_int[3])
    
    if id_type in id_type_wanted:
        
        image = cv2.rectangle(image, topleft, bottomright, color=color_dict[id_type], thickness=2)
        #image = cv2.putText(image, ('ID: ' + str(id_type)), topleft)
        image = cv2.putText(image, class_dict[id_type], topleft, font, 
                       fontScale=1, color=color_dict[id_type], thickness=5)
    
width = image.shape[1]
height = image.shape[0]
dim = (width, height)

# Display the image 
image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)

cv2.namedWindow("Image", cv2.WINDOW_NORMAL)
cv2.imshow(window_name, image)
cv2.waitKey(0)
cv2.destroyAllWindows()
